# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path='/content/drive/MyDrive/car_prices.csv'  # upload database
df = pd.read_csv(file_path)   # Read file using pandas
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df.isna().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %% [markdown]
# # Filling Null Values

# %%
df['make']=df['make'].fillna('other')

# %%
df['model']=df['model'].fillna('other')
df['color']=df['color'].fillna('other')
df['trim']=df['trim'].fillna('other')

# %%
df.isna().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color               0
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df.dropna(subset=['vin'],inplace=True)
df.dropna(subset=['saledate'],inplace=True)

# %%
df.isna().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body            13195
# transmission    65351
# vin                 0
# state               0
# condition       11816
# odometer           94
# color               0
# interior          749
# seller              0
# mmr                22
# sellingprice        0
# saledate            0
# dtype: int64

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df['odometer']=df['odometer'].fillna(df['odometer'].mean())
df['mmr']=df['mmr'].fillna(df['mmr'].mean())
df['condition']=df['condition'].fillna(df['condition'].mean())

# %%
df.isna().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body            13195
# transmission    65351
# vin                 0
# state               0
# condition           0
# odometer            0
# color               0
# interior          749
# seller              0
# mmr                 0
# sellingprice        0
# saledate            0
# dtype: int64

# %%
df['interior']=df['interior'].fillna(df['interior'].mode()[0])
df['body']=df['body'].fillna(df['body'].mode()[0])
df['transmission']=df['transmission'].fillna(df['transmission'].mode()[0])

# %%
df.isna().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df['state'] = df['state'].replace({'ab': 'Alberta','al' : 'Alabama','az' : 'Arizona','ca': 'California','co' : 'Colorado','fl' : 'Florida','ga' : 'Georgia','hi' : 'Hawaii','il' : 'Illinois','in' : 'Indiana','la' : 'Los Angeles','ma' : 'Massachusetts','md' : 'Mary Land','mi' : 'Michigan','mn' : 'Minnesota','mo' : 'Missouri','ms' : 'Mississippi','nc' : 'North Carolina','ne' : 'Nebraska','nj' : 'New Jersey','nm' : 'New Maxico','ns' : 'Nova Scotia','nv' : 'Nevada','ny' : 'New York','ok' : 'Oklahoma','on' : 'oh','oh': 'Ohio','or' : 'Oregon','pa' : 'Pennsylvania','pr' : 'Puerto Rico','qc' : 'Quebec','sc' : 'South Carolina','tn' : 'Tennessee','tx' : 'Texas','ut' : 'Utah','va' : 'Virginia','wi': 'Wisconsin', 'wa': 'Washington','3vwd17aj0fm227318' : 'West Virginia','3vwd17aj2fm258506' : 'Wyoming','3vwd17aj2fm261566' : 'Vermont','3vwd17aj2fm285365' : 'South Dakota','3vwd17aj3fm276741' : 'Rhode Island','3vwd17aj4fm201708' : 'North Dakota','3vwd17aj4fm236636' : 'New Hampshire','3vwd17aj5fm206111' : 'Montana','3vwd17aj5fm219943' : 'Maine','3vwd17aj5fm221322' : 'Louisiana','3vwd17aj5fm225953' : 'Kentucky','3vwd17aj5fm268964' : 'Kansas','3vwd17aj5fm273601' : 'Iowa','3vwd17aj5fm297123' : 'Idaho','3vwd17aj6fm218641' : 'Connecticut','3vwd17aj6fm231972' : 'Delaware','3vwd17aj7fm218440' : 'Arkansas','3vwd17aj7fm223475' : 'Alaska','3vwd17aj7fm229552' : 'Alaska','3vwd17aj7fm326640' : 'Alaska','3vwd17aj9fm219766' : 'Alaska','3vwd17ajxfm315938' : 'Alaska'})

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin       state  condition  odometer  \
# 0         automatic  5xyktca69fg566472  California        5.0   16639.0
# ...

# %%
# Save the filled dataset
df.to_csv('/content/drive/MyDrive/clean_car.csv', index=False)
